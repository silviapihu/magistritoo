# %% [markdown]
# <a href="https://colab.research.google.com/github/silviapihu/magistritoo/blob/master/joonised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# viiuldiagrammid ja tulpdiagrammid tunnuste jaotuse võrdlemiseks

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0a0bbb4c-5e48-48e7-b26d-76bd78f57ed3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a0bbb4c-5e48-48e7-b26d-76bd78f57ed3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving koos2.csv to koos2.csv

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import io
koos = pd.read_csv(io.BytesIO(uploaded['koos2.csv']))

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94067452-1b10-4dc9-9904-bb418a2e5ac3" name="files[]" multiple disabled />
#      <output id="result-94067452-1b10-4dc9-9904-bb418a2e5ac3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaaluiive.csv to kaaluiive.csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['kaaluiive.csv']))

# %%
koos.describe()
# Out:
#              Valim        Vanus  ...  WeightZScore  Makrosoomia
# count  5017.000000  5017.000000  ...   5010.000000  5017.000000
# mean      2.138529    29.337932  ...      0.679593     0.115607
# std       0.739725     5.333077  ...      0.945916     0.319785
# min       1.000000    14.000000  ...     -2.877500     0.000000
# 25%       2.000000    26.000000  ...      0.057050     0.000000
# 50%       2.000000    29.000000  ...      0.700000     0.000000
# 75%       3.000000    33.000000  ...      1.330025     0.000000
# max       3.000000    47.000000  ...      4.000000     1.000000
#
# [8 rows x 15 columns]

# %%
df2.describe()
# Out:
#          kaaluiive
# count  2006.000000
# mean     12.861316
# std       4.883151
# min      -6.500000
# 25%      10.000000
# 50%      12.800000
# 75%      15.500000
# max      36.000000

# %%
df=pd.merge(df1, df2, on='HPnumber', how='left')

# %%
koos.describe()
# Out:
#              valim        vanus  ...  WeightCentile  makrosoomia
# count  5017.000000  5017.000000  ...    5011.000000  5017.000000
# mean      2.138529    29.343432  ...      69.273598     0.115607
# std       0.739725     5.336919  ...      25.524556     0.319785
# min       1.000000    14.000000  ...       0.000000     0.000000
# 25%       2.000000    26.000000  ...      52.000000     0.000000
# 50%       2.000000    29.000000  ...      76.000000     0.000000
# 75%       3.000000    33.000000  ...      91.000000     0.000000
# max       3.000000    47.000000  ...     100.000000     1.000000
#
# [8 rows x 19 columns]

# %%
df.to_csv('df.csv') 
files.download('df.csv')

# %%
sns.set(style="whitegrid")
ax = sns.violinplot(x="makrosoomia", y="gdm_jm", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('GDMviolin.png')
files.download('GDMviolin.png')

# %%
ax = sns.violinplot(x="makrosoomia", y="KMI", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('KMIviolin.png')
files.download('KMIviolin.png')

# %%
ax = sns.violinplot(x="makrosoomia", y="vanus", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('vanus_violin.png')
files.download('vanus_violin.png')

# %%
ax = sns.violinplot(x="makrosoomia", y="ema_kaal", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('kaal_violin.png')
files.download('kaal_violin.png')

# %%
ax = sns.violinplot(x="risk_gdm", y="synnikaal", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('kaal_violin.png')
files.download('kaal_violin.png')

# %%
ax = sns.violinplot(x="polyhydramnion", y="synnikaal", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('poly_violin.png')
files.download('poly_violin.png')

# %%
ax = sns.violinplot(x="glykoos", y="WeightZScore", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('glykoos_violin.png')
files.download('glykoos_violin.png')

# %%
ax = sns.violinplot(x="GDM", y="synnikaal", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('GDM_violin.png')
files.download('GDM_violin.png')

# %%
ax = sns.violinplot(x="suur_laps_varem", y="synnikaal", hue="sugu", data=koos, palette="muted")
ax.get_figure().savefig('suurlaps_violin.png')
files.download('suurlaps_violin.png')

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="makrosoomnelaps", y="synn_med", hue="sugu", kind ='bar', data=df)

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="makrosoomnelaps", y="synn_med", hue="gdm_jahei", kind ='bar', data=df)

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="makrosoomnelaps", y="iVF_rasedus", hue="sugu", kind ='bar', data=df)

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="makrosoomnelaps", y="iVF_rasedus", hue="gdm_jahei", kind ='bar', data=df)

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="makrosoomnelaps", y="preekl", hue="sugu", kind ='bar', data=df, palette="muted")

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="makrosoomnelaps", y="preekl", hue="gdm_jahei", kind ='bar', data=df, palette="muted")

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="gdm_jahei", y="makrosoomnelaps", hue="gdm_test", kind ='bar', data=df, palette="muted")

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="makrosoomnelaps", y="suur_laps_varem", hue="sugu", kind ='bar', data=df, palette="muted")

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="gdm_jahei", y="varemGDM", hue="sugu", kind ='bar', data=df, palette="muted")

# %%
sns.set(style="whitegrid")
ax = sns.catplot(x="gdm_jahei", y="perek_diab", hue="sugu", kind ='bar', data=df, palette="muted")
